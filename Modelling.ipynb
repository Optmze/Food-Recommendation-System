# %%
#Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

# %%
sns.set_theme()
sns.set(style='darkgrid')

# %%
df1=pd.read_csv("indian_food.csv")
df2=pd.read_csv("IndianFoodDatasetCSV.csv")
#df3=pd.read_csv("Indian_Food_DF.csv")

# %%
df1["course"].value_counts()
# Out:
# course
# main course    129
# dessert         85
# snack           39
# starter          2
# Name: count, dtype: int64

# %%
englishdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 englishdf
#
# NameError: name 'englishdf' is not defined

# %%
df1.iloc[10:89]
# Out:
#             name                                        ingredients  \
# 10         Laddu                            Gram flour, ghee, sugar
# 11         Lassi                          Yogurt, milk, nuts, sugar
# 12     Nankhatai  Refined flour, besan, ghee, powdered sugar, yo...
# 13         Petha  Firm white pumpkin, sugar, kitchen lime, alum ...
# 14        Phirni                                  Rice, sugar, nuts
# ..           ...                                                ...
# 84     Daal puri  Moong dal, garam masala powder, garlic, green ...
# 85  Dal makhani   Red kidney beans, urad dal, cream, garam masal...
# 86     Dal tadka  Pigeon peas, garam masala, ginger, red onion, ...
# 87      Dum aloo  Baby potatoes, garam masala, cashew nuts, kasu...
# 88          Poha  Beaten rice flakes, potato, curry leaves, gree...
#
#           diet  prep_time  cook_time flavor_profile       course  \
# 10  vegetarian         10         40          sweet      dessert
# ...

# %%
df1.course.value_counts()
# Out:
# course
# main course    129
# dessert         85
# snack           39
# starter          2
# Name: count, dtype: int64

# %%
df2.head()
# Out:
#    Srno                                         RecipeName  \
# 0     1                               Masala Karela Recipe
# 1     2  टमाटर पुलियोगरे रेसिपी - Spicy Tomato Rice (Re...
# 2     3  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     4  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     5  आंध्रा स्टाइल आलम पचड़ी रेसिपी - Adrak Chutney ...
#
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                          Ingredients  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...
# 1  2-1/2 कप चावल - पका ले,3 टमाटर,3 छोटा चमच्च बी...
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...
# 3  500 grams Chicken,2 Onion - chopped,1 Tomato -...
# ...

# %%
df2.isnull().sum()
# Out:
# Srno                      0
# RecipeName                0
# TranslatedRecipeName      0
# Ingredients               6
# TranslatedIngredients     6
# PrepTimeInMins            0
# CookTimeInMins            0
# TotalTimeInMins           0
# Servings                  0
# Cuisine                   0
# Course                    0
# Diet                      0
# Instructions              0
# TranslatedInstructions    0
# URL                       0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['Srno', 'RecipeName', 'TranslatedRecipeName', 'Ingredients',
#        'TranslatedIngredients', 'PrepTimeInMins', 'CookTimeInMins',
#        'TotalTimeInMins', 'Servings', 'Cuisine', 'Course', 'Diet',
#        'Instructions', 'TranslatedInstructions', 'URL'],
#       dtype='object')

# %%
df2.shape
# Out:
# (6871, 15)

# %%
df2.drop(columns=["Srno","RecipeName","Ingredients","Instructions","URL"],inplace=True)

# %%
df2.dropna(inplace=True)

# %%
df2.head()
# Out:
#                                 TranslatedRecipeName  \
# 0                               Masala Karela Recipe
# 1                         Spicy Tomato Rice (Recipe)
# 2  Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3  Gongura Chicken Curry Recipe - Andhra Style Go...
# 4  Andhra Style Alam Pachadi Recipe - Adrak Chutn...
#
#                                TranslatedIngredients  PrepTimeInMins  \
# 0  6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...              15
# 1  2-1 / 2 cups rice - cooked, 3 tomatoes, 3 teas...               5
# 2  1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...              20
# 3  500 grams Chicken,2 Onion - chopped,1 Tomato -...              15
# 4  1 tablespoon chana dal, 1 tablespoon white ura...              10
#
#    CookTimeInMins  TotalTimeInMins  Servings               Cuisine  \
# 0              30               45         6                Indian
# 1              10               15         3  South Indian Recipes
# ...

# %%
df2.Course.value_counts()
# Out:
# Course
# Lunch                           1763
# Side Dish                        992
# Snack                            876
# Dinner                           781
# Dessert                          659
# Appetizer                        637
# Main Course                      315
# South Indian Breakfast           260
# World Breakfast                  260
# North Indian Breakfast           122
# Indian Breakfast                 101
# Vegetarian                        47
# One Pot Dish                      33
# High Protein Vegetarian            7
# Brunch                             4
# Vegan                              3
# Non Vegeterian                     2
# Eggetarian                         1
# No Onion No Garlic (Sattvic)       1
# Sugar Free Diet                    1
# Name: count, dtype: int64

# %%
# !pip install langdetect
# Out:
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: C:\Users\urwit\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      - ------------------------------------- 41.0/981.5 kB 1.9 MB/s eta 0:00:01
#      ---- --------------------------------- 112.6/981.5 kB 1.3 MB/s eta 0:00:01
#      ----- -------------------------------- 143.4/981.5 kB 1.2 MB/s eta 0:00:01
#      ------- ------------------------------ 204.8/981.5 kB 1.1 MB/s eta 0:00:01
#      -------- ----------------------------- 225.3/981.5 kB 1.1 MB/s eta 0:00:01
#      ----------- -------------------------- 286.7/981.5 kB 1.0 MB/s eta 0:00:01
#      ------------ ------------------------- 317.4/981.5 kB 1.0 MB/s eta 0:00:01
#      ------------- ---------------------- 368.6/981.5 kB 998.3 kB/s eta 0:00:01
#      --------------- ---------------------- 409.6/981.5 kB 1.0 MB/s eta 0:00:01
# ...

# %%
from langdetect import detect
import pandas as pd

# Assuming df is your DataFrame containing the "TranslatedIngredients" column
# Replace 'df' with the actual name of your DataFrame if it's different

# Function to detect language
def detect_language(text):
    try:
        lang = detect(text)
        return lang
    except:
        # Return None if language detection fails
        return None

# Apply language detection to each ingredient and create a boolean mask for English entries
english_mask = df2['TranslatedIngredients'].apply(lambda x: detect_language(x) == 'en')

# Filter DataFrame to keep only the English entries
english_df = df2[english_mask]

# Print count of non-English entries before dropping
print("Number of non-English entries before dropping:", len(df2) - sum(english_mask))

# Drop non-English entries
english_df = df2[df2['TranslatedIngredients'].apply(lambda x: detect_language(x) == 'en')]

# Print count of non-English entries after dropping
print("Number of non-English entries after dropping:", len(df2) - len(english_df))

# Optionally, reset index
english_df.reset_index(drop=True, inplace=True)

# Now 'english_df' contains only the English entries
# Out:
# Number of non-English entries before dropping: 589
# Number of non-English entries after dropping: 587

# %%
english_df['TranslatedIngredients'][0]
# Out:
# '6 Karela (Bitter Gourd/ Pavakkai) - deseeded,Salt - to taste,1 Onion - thinly sliced,3 tablespoon Gram flour (besan),2 teaspoons Turmeric powder (Haldi),1 tablespoon Red Chilli powder,2 teaspoons Cumin seeds (Jeera),1 tablespoon Coriander Powder (Dhania),1 tablespoon Amchur (Dry Mango Powder),Sunflower Oil - as required'

# %%
english_df.to_csv('foods.csv', index=False)

# %%
english_df.describe
# Out:
# <bound method NDFrame.describe of                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# 1                            Spicy Tomato Rice (Recipe)
# 2     Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# ...                                                 ...
# 6273                         Saffron Paneer Peda Recipe
# 6274  Italian Arancini Rice Balls Recipe With Delici...
# 6275        Quinoa Phirnee Recipe (Quinoa Milk Pudding)
# 6276      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6277  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
#
#                                   TranslatedIngredients  PrepTimeInMins  \
# 0     6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...              15
# 1     2-1 / 2 cups rice - cooked, 3 tomatoes, 3 teas...               5
# ...

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the prep time column
prep_times = df2['TotalTimeInMins']

# Create a histogram
plt.figure(figsize=(10, 6))
plt.xlim(0, 1000)
plt.ylim(0, 1000)
plt.hist(prep_times, bins=20, color='skyblue', edgecolor='black', alpha=0.7)

# Add labels and title
plt.xlabel('Preparation Time (mins)')
plt.ylabel('Frequency')
plt.title('Distribution of Preparation Time')

# Show plot
plt.grid(True)
plt.show()

# %%
# Visualizing the cuisines
plt.figure(figsize=(15, 15))
sns.countplot(y='Cuisine', data=df2, order=df2['Cuisine'].value_counts().index)
plt.title('Distribution of Cuisines')
plt.xlabel('Number of Recipes')
plt.ylabel('Cuisine')
plt.show()
# Out:
# C:\Users\urwit\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65279 (\N{ZERO WIDTH NO-BREAK SPACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df2['Course'].value_counts()
# Out:
# Course
# Lunch                           1763
# Side Dish                        992
# Snack                            876
# Dinner                           781
# Dessert                          659
# Appetizer                        637
# Main Course                      315
# South Indian Breakfast           260
# World Breakfast                  260
# North Indian Breakfast           122
# Indian Breakfast                 101
# Vegetarian                        47
# One Pot Dish                      33
# High Protein Vegetarian            7
# Brunch                             4
# Vegan                              3
# Non Vegeterian                     2
# Eggetarian                         1
# No Onion No Garlic (Sattvic)       1
# Sugar Free Diet                    1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Course', data=df2, order=df2['Course'].value_counts().index)
plt.title('Distribution of Courses')
plt.xlabel('Number of Recipes')
plt.ylabel('Course')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Diet', data=df2, order=df2['Diet'].value_counts().index)
plt.title('Distribution of Diets')
plt.xlabel('Number of Recipes')
plt.ylabel('Diet')
plt.show()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6865 entries, 0 to 6870
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TranslatedRecipeName    6865 non-null   object
#  1   TranslatedIngredients   6865 non-null   object
#  2   PrepTimeInMins          6865 non-null   int64
#  3   CookTimeInMins          6865 non-null   int64
#  4   TotalTimeInMins         6865 non-null   int64
#  5   Servings                6865 non-null   int64
#  6   Cuisine                 6865 non-null   object
#  7   Course                  6865 non-null   object
#  8   Diet                    6865 non-null   object
#  9   TranslatedInstructions  6865 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 848.0+ KB

# %%
df2
# Out:
#                                    TranslatedRecipeName  \
# 0                                  Masala Karela Recipe
# 1                            Spicy Tomato Rice (Recipe)
# 2     Ragi Semiya Upma Recipe - Ragi Millet Vermicel...
# 3     Gongura Chicken Curry Recipe - Andhra Style Go...
# 4     Andhra Style Alam Pachadi Recipe - Adrak Chutn...
# ...                                                 ...
# 6866                        Goan Mushroom Xacuti Recipe
# 6867        Sweet Potato & Methi Stuffed Paratha Recipe
# 6868      Ullikadala Pulusu Recipe | Spring Onion Curry
# 6869  Kashmiri Style Kokur Yakhni Recipe-Chicken Coo...
# 6870                                 Navrang Dal Recipe
#
#                                   TranslatedIngredients  PrepTimeInMins  \
# 0     6 Karela (Bitter Gourd/ Pavakkai) - deseeded,S...              15
# 1     2-1 / 2 cups rice - cooked, 3 tomatoes, 3 teas...               5
# 2     1-1/2 cups Rice Vermicelli Noodles (Thin),1 On...              20
# ...

# %%
import requests

def get_nutritional_values(query):
    api_url = 'https://api.api-ninjas.com/v1/nutrition?query={}'.format(query)
    key = "zBfZ7IKBT2H35WjLi5B7vA==sBRJ7LmMh3CP9Vs4"
    response = requests.get(api_url, headers={'X-Api-Key': key})
    
    if response.status_code == requests.codes.ok:
        return response.json()
    else:
        print("Error:", response.status_code, response.text)
        return None

def sum_nutritional_values(recipe_nutrition):
    total_nutrition = {
        "calories": 0,
        "serving_size_g": 0,
        "fat_total_g": 0,
        "fat_saturated_g": 0,
        "protein_g": 0,
        "sodium_mg": 0,
        "potassium_mg": 0,
        "cholesterol_mg": 0,
        "carbohydrates_total_g": 0,
        "fiber_g": 0,
        "sugar_g": 0
    }
    
    for ingredient_nutrition in recipe_nutrition:
        for key, value in ingredient_nutrition.items():
            if key != "name":  # Skip the name field
                total_nutrition[key] += value
    
    return total_nutrition

def get_and_sum_nutritional_values(query):
    response = get_nutritional_values(query)
    if response:
        total_nutrition = sum_nutritional_values(response)
        return total_nutrition
    else:
        return None

# %%
for i in range(0,len(english_df["TranslatedIngredients"])):
    query=english_df["TranslatedIngredients"][i]
    total_nutrition = get_and_sum_nutritional_values(query)
    if total_nutrition:
        for nutrient, value in total_nutrition.items():
            english_df.loc[i, nutrient] = value
# Out:
# 3 cups Kohl rabi - peeled and sliced,1 Onion,1 Tomato - diced,1/4 cup Green peas (Matar),2 Dry Red Chillies,1/2 teaspoon Cumin seeds (Jeera),1/2 teaspoon Mustard seeds,1 teaspoon Black Urad Dal (Split),Curry leaves - few,1/4 teaspoon Turmeric powder (Haldi),1/2 teaspoon Red Chilli powder,1 tablespoon Coriander Powder (Dhania),2 tablespoons Dessicated Coconut,Salt - for taste
# {'calories': 441.3, 'serving_size_g': 1042.6250000000002, 'fat_total_g': 6.7, 'fat_saturated_g': 0.8, 'protein_g': 24.199999999999996, 'sodium_mg': 156, 'potassium_mg': 587, 'cholesterol_mg': 1, 'carbohydrates_total_g': 85.0, 'fiber_g': 31.200000000000003, 'sugar_g': 34.900000000000006}
# 4 Potatoes (Aloo) - boiled,1 Carrot (Gajjar) - grated,1 cup Cabbage (Patta Gobi/ Muttaikose) - finely chopped,1 Onion - finely chopped,1/2 teaspoon Red Chilli powder,1/4 teaspoon Turmeric powder (Haldi),1 teaspoon Coriander Powder (Dhania),1 teaspoon Garam masala powder,Salt - to taste,Sunflower Oil - for cooking
# ...

# %%
for i in range(0,len(english_df["TranslatedIngredients"])):
    if(english_df["calories"].iloc[i]>3000):
        english_df.loc[i, ["calories", "serving_size_g", "fat_total_g", "fat_saturated_g", "protein_g", "sodium_mg", "potassium_mg", "cholesterol_mg", "carbohydrates_total_g", "fiber_g", "sugar_g"]] = 0
        # ing=english_df["TranslatedIngredients"][i]
        # query=ing
        # total_nutrition = get_and_sum_nutritional_values(query)
        # print(total_nutrition)
        # if total_nutrition:
        #     for nutrient, value in total_nutrition.items():
        #         english_df.loc[i, nutrient] = value
# Out:
# C:\Users\urwit\AppData\Local\Temp\ipykernel_2608\1359566915.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   english_df.loc[i, ["calories", "serving_size_g", "fat_total_g", "fat_saturated_g", "protein_g", "sodium_mg", "potassium_mg", "cholesterol_mg", "carbohydrates_total_g", "fiber_g", "sugar_g"]] = 0

# %%
columns_with_high_calories = english_df[english_df['calories'] > 5000].shape[0]
print("Number of columns with calories greater than 3000:", columns_with_high_calories)
# Out:
# Number of columns with calories greater than 3000: 412

# %%
ing=english_df["TranslatedIngredients"][0]
query=ing
total_nutrition = get_and_sum_nutritional_values(query)
for nutrient, value in total_nutrition.items():
    english_df.loc[0, nutrient] = value

# %%
english_df.isnull().sum()
# Out:
# TranslatedRecipeName         0
# TranslatedIngredients        0
# PrepTimeInMins               0
# CookTimeInMins               0
# TotalTimeInMins              0
# Servings                     0
# Cuisine                      0
# Course                       0
# Diet                         0
# TranslatedInstructions       0
# calories                  1254
# serving_size_g            1254
# fat_total_g               1254
# fat_saturated_g           1254
# protein_g                 1254
# sodium_mg                 1254
# potassium_mg              1254
# cholesterol_mg            1254
# carbohydrates_total_g     1254
# fiber_g                   1254
# sugar_g                   1254
# dtype: int64

# %%
# Assuming your DataFrame is named 'df'
index_of_highest_calories = english_df['calories'].idxmax()
row_with_highest_calories = english_df.loc[index_of_highest_calories]
print("Index of the row with the highest calories:", index_of_highest_calories)
print("Row with the highest calories:")
print(row_with_highest_calories)
# Out:
# Index of the row with the highest calories: 4520
# Row with the highest calories:
# TranslatedRecipeName      Malvani crispy lady finger recipe - groundnut ...
# TranslatedIngredients     500 grams Bhindi (Lady Finger/Okra) - washed a...
# PrepTimeInMins                                                         10.0
# CookTimeInMins                                                         20.0
# TotalTimeInMins                                                        30.0
# Servings                                                                4.0
# Cuisine                                                             Malvani
# Course                                                               Dinner
# Diet                                                             Vegetarian
# TranslatedInstructions    To begin making the Malvani Kurkuri Bhindi Rec...
# calories                                                           737827.7
# ...

# %%
ing=english_df["TranslatedIngredients"].iloc[4520]
total_nutrition = get_and_sum_nutritional_values(query)
print(total_nutrition)
# Out:
# {'calories': 6670.799999999998, 'serving_size_g': 2695.4200000000005, 'fat_total_g': 394.99999999999994, 'fat_saturated_g': 78.19999999999999, 'protein_g': 343.40000000000003, 'sodium_mg': 2932, 'potassium_mg': 4380, 'cholesterol_mg': 953, 'carbohydrates_total_g': 556.7, 'fiber_g': 191.0, 'sugar_g': 59.49999999999999}

# %%
sns.boxplot(english_df["calories"])
# Out:
# <Axes: ylabel='calories'>

# %%
english_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 english_df.head()
#
# NameError: name 'english_df' is not defined

# %%
df1.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
df1.loc[0, ["calories", "serving_size_g", "fat_total_g", "fat_saturated_g", "protein_g", "sodium_mg", "potassium_mg", "cholesterol_mg", "carbohydrates_total_g", "fiber_g", "sugar_g"]] = 0

# %%
df1.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region  calories  serving_size_g  fat_total_g  fat_saturated_g  protein_g  \
# ...

# %%
for i in range(0,len(df1)):
        ing=df1["ingredients"][i]
        query=ing
        total_nutrition = get_and_sum_nutritional_values(query)
        if total_nutrition:
            for nutrient, value in total_nutrition.items():
                df1.loc[i, nutrient] = value

# %%
df1.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region  calories  serving_size_g  fat_total_g  fat_saturated_g  protein_g  \
# ...

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# name                     0
# ingredients              0
# diet                     0
# prep_time                0
# cook_time                0
# flavor_profile           0
# course                   0
# state                    0
# region                   0
# calories                 0
# serving_size_g           0
# fat_total_g              0
# fat_saturated_g          0
# protein_g                0
# sodium_mg                0
# potassium_mg             0
# cholesterol_mg           0
# carbohydrates_total_g    0
# fiber_g                  0
# sugar_g                  0
# dtype: int64

# %%
df1["serving_size_g"].value_counts()
# Out:
# serving_size_g
# 100.0    96
# 200.0    92
# 300.0    35
# 400.0     6
# 1.0       5
# 101.0     5
# 201.0     3
# 500.0     2
# Name: count, dtype: int64

# %%
# Normalize nutritional values to 100g
df1['serving_size_g'] = df1['serving_size_g'].astype(float)  # Convert serving_size_g to float type
columns_to_normalize = ["calories", "fat_total_g", "fat_saturated_g", "protein_g", "sodium_mg", 
                        "potassium_mg", "cholesterol_mg", "carbohydrates_total_g", "fiber_g", "sugar_g"]
for column in columns_to_normalize:
    df1[column] = df1[column] / (df1['serving_size_g'] / 100)

# %%
df1.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region    calories  serving_size_g  fat_total_g  fat_saturated_g  protein_g  \
# ...

# %%
df1.describe()
# Out:
#         prep_time   cook_time    calories  serving_size_g  fat_total_g  \
# count  244.000000  244.000000  244.000000      244.000000   244.000000
# mean    31.627049   34.672131  270.518450      176.282787    14.211462
# std     73.826430   49.307625  200.065689       87.011694    22.951784
# min     -1.000000   -1.000000    0.000000        1.000000     0.000000
# 25%     10.000000   20.000000  109.437500      100.000000     0.700000
# 50%     10.000000   30.000000  245.850000      200.000000     4.433333
# 75%     20.000000   40.000000  363.300000      200.000000    14.300000
# max    500.000000  720.000000  894.700000      500.000000   101.200000
#
#        fat_saturated_g   protein_g     sodium_mg  potassium_mg  \
# count       244.000000  244.000000    244.000000    244.000000
# mean          4.862973    6.511028   1124.245958    131.965664
# std          11.155557    5.660087   5485.063654    138.085357
# min           0.000000    0.000000      0.000000      0.000000
# ...

# %%
df1.to_csv('food_small.csv', index=False)

# %%
df1.columns.tolist()
# Out:
# ['name',
#  'ingredients',
#  'diet',
#  'prep_time',
#  'cook_time',
#  'flavor_profile',
#  'course',
#  'state',
#  'region',
#  'calories',
#  'serving_size_g',
#  'fat_total_g',
#  'fat_saturated_g',
#  'protein_g',
#  'sodium_mg',
#  'potassium_mg',
#  'cholesterol_mg',
#  'carbohydrates_total_g',
#  'fiber_g',
#  'sugar_g']

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
features=['prep_time','cook_time','flavor_profile','course','state','region','calories','serving_size_g','fat_total_g','fat_saturated_g','protein_g','sodium_mg','potassium_mg','cholesterol_mg','carbohydrates_total_g','fiber_g','sugar_g']
cat_columns = ['flavor_profile', 'course', 'state', 'region']
dft = pd.get_dummies(df1, columns=cat_columns)
numeric_features = dft.select_dtypes(include=['float64', 'int64']).dropna()
X = numeric_features[features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
n_neighbors = 5  # Number of neighbors to consider
model = NearestNeighbors(n_neighbors=n_neighbors)
model.fit(X_scaled)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 8
#       6 dft = pd.get_dummies(df1, columns=cat_columns)
#       7 numeric_features = dft.select_dtypes(include=['float64', 'int64']).dropna()
# ----> 8 X = numeric_features[features]
#       9 scaler = StandardScaler()
#      10 X_scaled = scaler.fit_transform(X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
# ...

# %%
df1.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='object')

# %%
english_df.columns
# Out:
# Index(['TranslatedRecipeName', 'TranslatedIngredients', 'PrepTimeInMins',
#        'CookTimeInMins', 'TotalTimeInMins', 'Servings', 'Cuisine', 'Course',
#        'Diet', 'TranslatedInstructions'],
#       dtype='object')
